# %%
# Result table as on 27-6-18
main("2")
# Out:
# +-------+------+--------------+--------+--------+----+----+----+
# | Group | Rank |   Country    | Played | Points | GF | GA | GD |
# +=======+======+==============+========+========+====+====+====+
# | A     | 1    | Uruguay      | 3      | 9      | 5  | 0  | 5  |
# +-------+------+--------------+--------+--------+----+----+----+
# | A     | 2    | Russia       | 3      | 6      | 8  | 4  | 4  |
# +-------+------+--------------+--------+--------+----+----+----+
# | A     | 3    | Saudi Arabia | 3      | 3      | 2  | 7  | -5 |
# +-------+------+--------------+--------+--------+----+----+----+
# | A     | 4    | Egypt        | 3      | 0      | 2  | 6  | -4 |
# +-------+------+--------------+--------+--------+----+----+----+
#
# +-------+------+----------+--------+--------+----+----+----+
# | Group | Rank | Country  | Played | Points | GF | GA | GD |
# +=======+======+==========+========+========+====+====+====+
# | B     | 1    | Spain    | 3      | 5      | 6  | 5  | 1  |
# +-------+------+----------+--------+--------+----+----+----+
# | B     | 2    | Portugal | 3      | 5      | 5  | 4  | 1  |
# +-------+------+----------+--------+--------+----+----+----+
# | B     | 3    | Iran     | 3      | 4      | 2  | 2  | 0  |
# +-------+------+----------+--------+--------+----+----+----+
# | B     | 4    | Morocco  | 3      | 1      | 2  | 4  | -2 |
# +-------+------+----------+--------+--------+----+----+----+
#
# +-------+------+-----------+--------+--------+----+----+----+
# | Group | Rank |  Country  | Played | Points | GF | GA | GD |
# +=======+======+===========+========+========+====+====+====+
# | C     | 1    | France    | 3      | 7      | 3  | 1  | 2  |
# +-------+------+-----------+--------+--------+----+----+----+
# | C     | 2    | Denmark   | 3      | 5      | 2  | 1  | 1  |
# +-------+------+-----------+--------+--------+----+----+----+
# | C     | 3    | Peru      | 3      | 3      | 2  | 2  | 0  |
# +-------+------+-----------+--------+--------+----+----+----+
# | C     | 4    | Australia | 3      | 1      | 2  | 5  | -3 |
# +-------+------+-----------+--------+--------+----+----+----+
#
# +-------+------+-----------+--------+--------+----+----+----+
# | Group | Rank |  Country  | Played | Points | GF | GA | GD |
# +=======+======+===========+========+========+====+====+====+
# | D     | 1    | Croatia   | 3      | 9      | 7  | 1  | 6  |
# +-------+------+-----------+--------+--------+----+----+----+
# | D     | 2    | Argentina | 3      | 4      | 3  | 5  | -2 |
# +-------+------+-----------+--------+--------+----+----+----+
# | D     | 3    | Nigeria   | 3      | 3      | 3  | 4  | -1 |
# +-------+------+-----------+--------+--------+----+----+----+
# | D     | 4    | Iceland   | 3      | 1      | 2  | 5  | -3 |
# +-------+------+-----------+--------+--------+----+----+----+
#
# +-------+------+-------------+--------+--------+----+----+----+
# | Group | Rank |   Country   | Played | Points | GF | GA | GD |
# +=======+======+=============+========+========+====+====+====+
# | E     | 1    | Brazil      | 2      | 4      | 3  | 1  | 2  |
# +-------+------+-------------+--------+--------+----+----+----+
# | E     | 2    | Switzerland | 2      | 4      | 3  | 2  | 1  |
# +-------+------+-------------+--------+--------+----+----+----+
# | E     | 3    | Serbia      | 2      | 3      | 2  | 2  | 0  |
# +-------+------+-------------+--------+--------+----+----+----+
# | E     | 4    | Costa Rica  | 2      | 0      | 0  | 3  | -3 |
# +-------+------+-------------+--------+--------+----+----+----+
#
# +-------+------+----------------+--------+--------+----+----+----+
# | Group | Rank |    Country     | Played | Points | GF | GA | GD |
# +=======+======+================+========+========+====+====+====+
# | F     | 1    | Mexico         | 2      | 6      | 3  | 1  | 2  |
# +-------+------+----------------+--------+--------+----+----+----+
# | F     | 2    | Germany        | 2      | 3      | 2  | 2  | 0  |
# +-------+------+----------------+--------+--------+----+----+----+
# | F     | 2    | Sweden         | 2      | 3      | 2  | 2  | 0  |
# +-------+------+----------------+--------+--------+----+----+----+
# | F     | 4    | Korea Republic | 2      | 0      | 1  | 3  | -2 |
# +-------+------+----------------+--------+--------+----+----+----+
#
# +-------+------+---------+--------+--------+----+----+----+
# | Group | Rank | Country | Played | Points | GF | GA | GD |
# +=======+======+=========+========+========+====+====+====+
# | G     | 1    | Belgium | 2      | 6      | 8  | 2  | 6  |
# +-------+------+---------+--------+--------+----+----+----+
# | G     | 1    | England | 2      | 6      | 8  | 2  | 6  |
# +-------+------+---------+--------+--------+----+----+----+
# | G     | 3    | Tunisia | 2      | 0      | 3  | 7  | -4 |
# +-------+------+---------+--------+--------+----+----+----+
# | G     | 4    | Panama  | 2      | 0      | 1  | 9  | -8 |
# +-------+------+---------+--------+--------+----+----+----+
#
# +-------+------+----------+--------+--------+----+----+----+
# | Group | Rank | Country  | Played | Points | GF | GA | GD |
# +=======+======+==========+========+========+====+====+====+
# | H     | 1    | Senegal  | 2      | 4      | 4  | 3  | 1  |
# +-------+------+----------+--------+--------+----+----+----+
# | H     | 1    | Japan    | 2      | 4      | 4  | 3  | 1  |
# +-------+------+----------+--------+--------+----+----+----+
# | H     | 3    | Colombia | 2      | 3      | 4  | 2  | 2  |
# +-------+------+----------+--------+--------+----+----+----+
# | H     | 4    | Poland   | 2      | 0      | 1  | 5  | -4 |
# +-------+------+----------+--------+--------+----+----+----+

# %%
# Result table as on 26-6-18
# main("2")
# Out:
# +-------+------+--------------+--------+--------+----+----+----+
# | Group | Rank |   Country    | Played | Points | GF | GA | GD |
# +=======+======+==============+========+========+====+====+====+
# | A     | 1    | Uruguay      | 3      | 9      | 5  | 0  | 5  |
# +-------+------+--------------+--------+--------+----+----+----+
# | A     | 2    | Russia       | 3      | 6      | 8  | 4  | 4  |
# +-------+------+--------------+--------+--------+----+----+----+
# | A     | 3    | Saudi Arabia | 3      | 3      | 2  | 7  | -5 |
# +-------+------+--------------+--------+--------+----+----+----+
# | A     | 4    | Egypt        | 3      | 0      | 2  | 6  | -4 |
# +-------+------+--------------+--------+--------+----+----+----+
#
# +-------+------+----------+--------+--------+----+----+----+
# | Group | Rank | Country  | Played | Points | GF | GA | GD |
# +=======+======+==========+========+========+====+====+====+
# | B     | 1    | Spain    | 3      | 5      | 6  | 5  | 1  |
# +-------+------+----------+--------+--------+----+----+----+
# | B     | 2    | Portugal | 3      | 5      | 5  | 4  | 1  |
# +-------+------+----------+--------+--------+----+----+----+
# | B     | 3    | Iran     | 3      | 4      | 2  | 2  | 0  |
# +-------+------+----------+--------+--------+----+----+----+
# | B     | 4    | Morocco  | 3      | 1      | 2  | 4  | -2 |
# +-------+------+----------+--------+--------+----+----+----+
#
# +-------+------+-----------+--------+--------+----+----+----+
# | Group | Rank |  Country  | Played | Points | GF | GA | GD |
# +=======+======+===========+========+========+====+====+====+
# | C     | 1    | France    | 2      | 6      | 3  | 1  | 2  |
# +-------+------+-----------+--------+--------+----+----+----+
# | C     | 2    | Denmark   | 2      | 4      | 2  | 1  | 1  |
# +-------+------+-----------+--------+--------+----+----+----+
# | C     | 3    | Australia | 2      | 1      | 2  | 3  | -1 |
# +-------+------+-----------+--------+--------+----+----+----+
# | C     | 4    | Peru      | 2      | 0      | 0  | 2  | -2 |
# +-------+------+-----------+--------+--------+----+----+----+
#
# +-------+------+-----------+--------+--------+----+----+----+
# | Group | Rank |  Country  | Played | Points | GF | GA | GD |
# +=======+======+===========+========+========+====+====+====+
# | D     | 1    | Croatia   | 2      | 6      | 5  | 0  | 5  |
# +-------+------+-----------+--------+--------+----+----+----+
# | D     | 2    | Nigeria   | 2      | 3      | 2  | 2  | 0  |
# +-------+------+-----------+--------+--------+----+----+----+
# | D     | 3    | Iceland   | 2      | 1      | 1  | 3  | -2 |
# +-------+------+-----------+--------+--------+----+----+----+
# | D     | 4    | Argentina | 2      | 1      | 1  | 4  | -3 |
# +-------+------+-----------+--------+--------+----+----+----+
#
# +-------+------+-------------+--------+--------+----+----+----+
# | Group | Rank |   Country   | Played | Points | GF | GA | GD |
# +=======+======+=============+========+========+====+====+====+
# | E     | 1    | Brazil      | 2      | 4      | 3  | 1  | 2  |
# +-------+------+-------------+--------+--------+----+----+----+
# | E     | 2    | Switzerland | 2      | 4      | 3  | 2  | 1  |
# +-------+------+-------------+--------+--------+----+----+----+
# | E     | 3    | Serbia      | 2      | 3      | 2  | 2  | 0  |
# +-------+------+-------------+--------+--------+----+----+----+
# | E     | 4    | Costa Rica  | 2      | 0      | 0  | 3  | -3 |
# +-------+------+-------------+--------+--------+----+----+----+
#
# +-------+------+----------------+--------+--------+----+----+----+
# | Group | Rank |    Country     | Played | Points | GF | GA | GD |
# +=======+======+================+========+========+====+====+====+
# | F     | 1    | Mexico         | 2      | 6      | 3  | 1  | 2  |
# +-------+------+----------------+--------+--------+----+----+----+
# | F     | 2    | Germany        | 2      | 3      | 2  | 2  | 0  |
# +-------+------+----------------+--------+--------+----+----+----+
# | F     | 2    | Sweden         | 2      | 3      | 2  | 2  | 0  |
# +-------+------+----------------+--------+--------+----+----+----+
# | F     | 4    | Korea Republic | 2      | 0      | 1  | 3  | -2 |
# +-------+------+----------------+--------+--------+----+----+----+
#
# +-------+------+---------+--------+--------+----+----+----+
# | Group | Rank | Country | Played | Points | GF | GA | GD |
# +=======+======+=========+========+========+====+====+====+
# | G     | 1    | Belgium | 2      | 6      | 8  | 2  | 6  |
# +-------+------+---------+--------+--------+----+----+----+
# | G     | 1    | England | 2      | 6      | 8  | 2  | 6  |
# +-------+------+---------+--------+--------+----+----+----+
# | G     | 3    | Tunisia | 2      | 0      | 3  | 7  | -4 |
# +-------+------+---------+--------+--------+----+----+----+
# | G     | 4    | Panama  | 2      | 0      | 1  | 9  | -8 |
# +-------+------+---------+--------+--------+----+----+----+
#
# +-------+------+----------+--------+--------+----+----+----+
# | Group | Rank | Country  | Played | Points | GF | GA | GD |
# +=======+======+==========+========+========+====+====+====+
# | H     | 1    | Senegal  | 2      | 4      | 4  | 3  | 1  |
# +-------+------+----------+--------+--------+----+----+----+
# | H     | 1    | Japan    | 2      | 4      | 4  | 3  | 1  |
# +-------+------+----------+--------+--------+----+----+----+
# | H     | 3    | Colombia | 2      | 3      | 4  | 2  | 2  |
# +-------+------+----------+--------+--------+----+----+----+
# | H     | 4    | Poland   | 2      | 0      | 1  | 5  | -4 |
# +-------+------+----------+--------+--------+----+----+----+

# %%
# Get Football World Cup 2018 details
# Version: 0.1
# Created by: Harleen Mann
# Last modified date: 25-6-18

# v0.1: get tournament name
#       get table standings

import requests
import sys
import json
import texttable

URL = "http://api.football-data.org/v1/"
headers = {
    "X-Auth-Token": "14c82fcc05f14df483676b5edd94c555",
    "X-Response-Control": "minified"
}


def get_competition():
    return requests.get(URL + "competitions/467", headers=headers)

def get_table():
    return requests.get(URL + "competitions/467/leagueTable", headers=headers)

def main(argv):    
    if (argv == "1"):
        result = get_competition().json()
        print(result['caption'])

    if (argv == "2"):
        result = get_table().json()

        for groupName in ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']:
            table = texttable.Texttable()
            ref = result['standings'][groupName]
            l = [["Group", "Rank", "Country", "Played", "Points", "GF", "GA", "GD"]]
            for team in range(0, len(ref)):
                teamRow = list(ref[team].values())
                l.append(teamRow[:3] + teamRow[4:5] + teamRow[6:])
            table.add_rows(l)
            print(table.draw() + "\n")

if __name__ == '__main__':
    if len(sys.argv) <= 1:
        print("usage: python try-requests.py x \n"
              "\t \t where x can be \n \t \t 1 for tournament name \n \t \t 2 for league table")
    else:
        main(sys.argv[1])
