# %%
import wcup2018Group, wcup2018Knockout
import os, datetime

os.environ['http_proxy'] = ''
os.environ['https_proxy'] = ''

print('Last run on ' + str(datetime.datetime.now()) + ' Melbourne local time')
wcup2018Knockout.run([])
wcup2018Group.run("groupStage")
# Out:
# Last run on 2018-07-02 22:56:27.248772 Melbourne local time
# +---------------------------------------------------------------------------------------------------+
# ---------------------------------FIFA WORLDCUP 2018 KNOCK-OUT STAGE----------------------------------
# +-------------------------------------------------------------------------------------------------------+
# | +-------------+-------+                                                                               |
# | | 2018-06-30  |       |                                                                               |
# | +-------------+-------+   _ _ _ _ _ _          .                                                      |
# | | France      | 4     |              |                                                                |
# | +-------------+-------+              |                                                                |
# ...

# %%
import wcup2018Group, wcup2018Knockout
import os, datetime

os.environ['http_proxy'] = ''

print('Last run on ' + str(datetime.date.today()))
wcup2018Knockout.run([])
wcup2018Group.run("groupStage")
# Out:
# Last run on 2018-07-01
# +---------------------------------------------------------------------------------------------------+
# ---------------------------------FIFA WORLDCUP 2018 KNOCK-OUT STAGE----------------------------------
# +---------------------------------------------------------------------------------------------------+
# | +-------------+------+                                                                            |
# | | 2018-06-30  |      |                                                                            |
# | +-------------+------+   _ _ _ _ _ _          .                                                   |
# | | France      | 4    |             |                                                              |
# | +-------------+------+             |                                                              |
# | | Argentina   | 3    |             |                                                              |
# ...
